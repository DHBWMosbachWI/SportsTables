# %%
### extract all data for nfl
from dotenv import load_dotenv
load_dotenv(override=True)
import os
from os.path import join
import time
from selenium import webdriver

from web_scraping import web_table_to_dataframe, get_nhl_season_standings, get_all_nhl_teams, get_nhl_player_stats, get_nhl_player_goalie_stats, get_nhl_playoff_standings, get_nhl_playoff_player_stats, get_nhl_playoff_player_goalies_stats

options = webdriver.EdgeOptions()
options.add_argument('headless')
driver = webdriver.Edge(r'../msedgedriver.exe', options=options) # ToDo better way of using driver files


time.sleep(3)
'''
df = get_all_nhl_teams(driver) # works
df[0].to_csv(join(os.environ["SportsTables"], "hockey", f"all_nhl_teams.csv"), index=False)
df[1].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_WHA_and_Defunct_Franchise_.csv"), index=False)

time.sleep(3)
'''
for year in range(1980,2000):

    print(year)

    #df = get_nhl_player_stats(year, driver) # uses selenium
    #df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_player_stats_{year}.csv"), index=False) #works

    #time.sleep(3)
    '''
    df = get_nhl_season_standings(year,driver) # uses selenium
    df[0].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings1_{year}.csv"), index=False)
    df[1].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings2_{year}.csv"), index=False)
    df[2].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings1_{year}.csv"), index=False)
    df[3].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_all_teams2_{year}.csv"), index=False)
    df[4].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_{year}.csv"), index=False)
    df[5].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_teams_statics_{year}.csv"), index=False)
    df[6].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_award_{year}.csv"), index=False)
    df[7].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_all_star_1st_team_2st_team_{year}.csv"), index=False)
    df[8].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_{year}.csv"), index=False)

    time.sleep(3)
    '''
    #df = get_nhl_player_goalie_stats(year, driver)
    #df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_player_goalie_stats_{year}.csv"), index=False) #works

    #time.sleep(3)

    df = get_nhl_playoff_standings(year, driver)
    df[0].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_playoff_standings_{year}.csv"), index=False)
    df[1].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_{year}.csv"), index=False)
    df[2].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_teams_statics_{year}.csv"), index=False)
    df[3].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_overtime_goals_{year}.csv"), index=False)
    df[4].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_{year}.csv"), index=False)
    time.sleep(3)

    '''
    df = get_nhl_playoff_player_stats(year, driver) #works
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_playoff_player_stats_{year}.csv"), index=False)

    time.sleep(3)

    df = get_nhl_playoff_player_goalies_stats(year, driver)
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_playoff_player_goalies_stats_{year}.csv"), index=False) #works

    time.sleep(3)
    '''
driver.quit()
# Out:
# C:\Users\krist\AppData\Local\Temp\ipykernel_22012\1069066429.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(r'../msedgedriver.exe', options=options) # ToDo better way of using driver files
# 1980
# [                                                    0  \
# 0                                               Final
# 1   Game 1  May 13  New York Islanders  4  Philade...
# 2                                              Game 1
# 3                                              Game 2
# 4                                              Game 3
# ..                                                ...
# 95                                  Preliminary Round
# 96  Game 1  April 8  Edmonton Oilers  3  Philadelp...
# 97                                             Game 1
# 98                                             Game 2
# 99                                             Game 3
#
# ...
