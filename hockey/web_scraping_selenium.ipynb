# %%
### extract all data for nfl
from dotenv import load_dotenv
load_dotenv(override=True)
import os
from os.path import join
import time
from selenium import webdriver

from web_scraping import web_table_to_dataframe, get_nhl_season_standings, get_all_nhl_teams, get_nhl_player_stats, get_nhl_player_goalie_stats, get_nhl_playoff_standings, get_nhl_playoff_player_stats, get_nhl_playoff_player_goalies_stats, get_nhl_season_standings_zusatz, get_nhl_hat_tricks, get_nhl_penalty_shots, get_nhl_debuts, get_nhl_final_season, get_nhl_births, get_nhl_deaths

options = webdriver.EdgeOptions()
options.add_argument('headless')
driver = webdriver.Edge(r'../msedgedriver.exe', options=options) # ToDo better way of using driver files


time.sleep(3)

df = get_all_nhl_teams(driver) # works
df[0].to_csv(join(os.environ["SportsTables"], "hockey", f"all_nhl_teams.csv"), index=False)
df[1].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_WHA_and_Defunct_Franchise.csv"), index=False)

time.sleep(3)

for year in range(1980,2000):
    print(year)

    df = get_nhl_player_stats(year, driver) # uses selenium
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_player_stats_{year}.csv"), index=False) #works
    time.sleep(3)

    df = get_nhl_season_standings(year,driver) # uses selenium
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_Clarence_Campbell_Conference_&_Prince_of_Wales_Conference_{year}.csv"), index=False)
    time.sleep(3)

    df = get_nhl_season_standings_zusatz(year, driver)
    df[0].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_{year}.csv"), index=False) #richtig
    df[1].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_final_{year}.csv"), index=False)#richtig
    df[2].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_semi_finals1_{year}.csv"), index=False)#richtig
    df[3].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_semi_finals2_{year}.csv"), index=False)#richtig
    df[4].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_quarter-finals1_{year}.csv"), index=False)#richtig
    df[5].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_quarter-finals2_{year}.csv"), index=False)
    df[6].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_quarter-finals3_{year}.csv"), index=False) #richtig
    df[7].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_quarter-finals4_{year}.csv"), index=False)
    df[8].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_conference_PreliminaryRound1_{year}.csv"), index=False)
    df[9].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_PreliminaryRound2_{year}.csv"), index=False)
    df[10].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_playoff_series_conference_PreliminaryRound3_{year}.csv"), index=False)
    df[11].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_playoff_series_conference_PreliminaryRound4_{year}.csv"), index=False)
    df[12].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_playoff_series_conference_PreliminaryRound5_{year}.csv"), index=False)
    df[13].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_playoff_series_conference_PreliminaryRound6_{year}.csv"), index=False)
    df[14].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_playoff_series_conference_PreliminaryRound7_{year}.csv"), index=False)
    df[15].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_playoff_series_conference_PreliminaryRound8_{year}.csv"), index=False)
    df[16].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_teams_statics_{year}.csv"), index=False)
    df[17].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_awards_{year}.csv"), index=False)
    df[18].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_leaders_goals_{year}.csv"), index=False) # ab hier nicht übertragen
    df[19].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_leaders_assists_{year}.csv"), index=False)
    df[20].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_leaders_points_{year}.csv"), index=False)
    df[21].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_leaders_goals_created_{year}.csv"), index=False)
    df[22].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_leaders_plus_minus_{year}.csv"), index=False)
    df[23].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_penalties_in_minutes_{year}.csv"), index=False)
    df[24].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_Even_Strength_Goals_{year}.csv"), index=False)
    df[25].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_power_play_goals_{year}.csv"), index=False)
    df[26].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_shot_handed_goals_{year}.csv"), index=False)
    df[27].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_game_winning_goals_{year}.csv"), index=False)
    df[28].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_shots_{year}.csv"), index=False)
    df[29].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_shooting_percentage_{year}.csv"), index=False)
    df[30].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_hat_tricks_{year}.csv"), index=False)
    df[31].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_goals_per_game_{year}.csv"), index=False)
    df[32].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_assists_per_game_{year}.csv"), index=False)
    df[33].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_points_per_game_{year}.csv"), index=False)
    df[34].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_goals_created_per_game_{year}.csv"), index=False)
    df[35].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_total_goals_on_ice_for_{year}.csv"), index=False)
    df[36].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_power_play_goals_on_ice_for_{year}.csv"), index=False)
    df[37].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_total_goals_on_ice_against_{year}.csv"), index=False)
    df[38].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_power_play_Goals_on_ice_Against_{year}.csv"), index=False)
    df[39].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_games_played_goalie_{year}.csv"), index=False)
    df[40].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_wins_{year}.csv"), index=False)
    df[41].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_losses_{year}.csv"), index=False)
    df[42].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_ties_plus_OTSO_losses_{year}.csv"), index=False)
    df[43].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_goals_against_{year}.csv"), index=False)
    df[44].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_shots_against_{year}.csv"), index=False)
    df[45].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_saves_{year}.csv"), index=False)
    df[46].to_csv(join(os.environ["SportsTables"], "hockey", f"save_percentage_{year}.csv"), index=False)
    df[47].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_goals_against_average_{year}.csv"), index=False)
    df[48].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_shutouts_{year}.csv"), index=False)
    df[49].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_minutes_{year}.csv"), index=False)
    df[50].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_goals_saved_above_average_{year}.csv"), index=False) #PRÜFEN
    df[51].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_goals_allowed_adjusted_{year}.csv"), index=False)
    df[52].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_offensive_point_shares_{year}.csv"), index=False)
    df[53].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_defensive_point_shares_{year}.csv"), index=False)
    df[54].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_goalie_point_shares_{year}.csv"), index=False)
    df[55].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_point_shares_{year}.csv"), index=False)
    time.sleep(3)


    df = get_nhl_player_goalie_stats(year, driver)
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_player_goalie_stats_{year}.csv"), index=False) #works

    time.sleep(3)

    df = get_nhl_playoff_standings(year, driver)
    df[0].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_{year}.csv"), index=False)
    df[2].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_Conference_Finals_{year}.csv"), index=False)
    df[3].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_Conference_Finals2_{year}.csv"), index=False)
    df[4].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_division_finals_{year}.csv"), index=False)
    df[5].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_division_finals2_{year}.csv"), index=False)
    df[6].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_division_finals3_{year}.csv"), index=False)
    df[7].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_division_finals4_{year}.csv"), index=False)
    df[8].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_division_semi_finals1_{year}.csv"), index=False)
    df[9].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_division_semi_finals2_{year}.csv"), index=False)
    df[10].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_division_semi_finals3_{year}.csv"), index=False)
    df[11].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_division_semi_finals4_{year}.csv"), index=False)
    df[12].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_division_semi_finals5_{year}.csv"), index=False)
    df[13].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_division_semi_finals6_{year}.csv"), index=False)
    df[14].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_division_semi_finals7_{year}.csv"), index=False)
    df[15].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_division_semi_finals8_{year}.csv"), index=False)
    df[16].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_teams_statics_{year}.csv"), index=False)
    df[17].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_overtime_goals_{year}.csv"), index=False)
    df[18].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_goals_{year}.csv"), index=False)
    df[19].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_goals_assists_{year}.csv"), index=False)
    df[20].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_games_points_{year}.csv"), index=False)
    df[21].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_goals_created_{year}.csv"), index=False)
    df[22].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_plus-minus_{year}.csv"), index=False)
    df[23].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_penalties_in_minutes_{year}.csv"), index=False)
    df[24].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_even_strength_for_goals_{year}.csv"), index=False)
    df[25].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_saves_power_play_goals_{year}.csv"), index=False)
    df[26].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_short_handed_goals_{year}.csv"), index=False)
    df[27].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_game_winning_goals_{year}.csv"), index=False)
    df[28].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_shots_{year}.csv"), index=False)
    df[29].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_shooting_percentage_{year}.csv"), index=False)
    df[30].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_hat_ticks_{year}.csv"), index=False) #
    df[31].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_goals_per_game_{year}.csv"), index=False)
    df[32].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_assists_per_game_{year}.csv"), index=False)
    df[33].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_points_per_game_{year}.csv"), index=False)
    df[34].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_goals_created_per_game_{year}.csv"), index=False)
    df[35].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_games_played_goalie_{year}.csv"), index=False)
    df[36].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_wins_{year}.csv"), index=False)
    df[37].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_losses_{year}.csv"), index=False)
    df[38].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_goals_against_{year}.csv"), index=False)
    df[39].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_shots_against_{year}.csv"), index=False)
    df[40].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_saves_{year}.csv"), index=False)
    df[41].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_save_percentage_{year}.csv"), index=False)
    df[42].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_goals_against_average_{year}.csv"), index=False)
    df[43].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_shutouts_{year}.csv"), index=False)
    df[44].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_minutes_{year}.csv"), index=False)
    time.sleep(3)

    df = get_nhl_playoff_player_stats(year, driver) #works
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_playoff_player_stats_{year}.csv"), index=False)

    time.sleep(3)

    df = get_nhl_playoff_player_goalies_stats(year, driver)
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_playoff_player_goalies_stats_{year}.csv"), index=False) #works

    time.sleep(3)

#FEHLENDE LINKS TABELLEN
    df = get_nhl_hat_tricks(year, driver)
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_hat_tricks1_{year}.csv"), index=False) #works
    time.sleep(3)


    df = get_nhl_penalty_shots(year, driver)
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_penalty_shots1_{year}.csv"), index=False) #works
    time.sleep(3)

    df = get_nhl_debuts(year, driver)
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_debut_{year}.csv"), index=False) #works
    time.sleep(3)

    df = get_nhl_final_season(year, driver)
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_finales1_{year}.csv"), index=False) #works
    time.sleep(3)

    df = get_nhl_births(year, driver)
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_births_{year}.csv"), index=False) #works
    time.sleep(3)

    df = get_nhl_deaths(year, driver)
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_deaths_{year}.csv"), index=False) #works
    time.sleep(3)

driver.quit()
# Out:
# C:\Users\krist\AppData\Local\Temp\ipykernel_12604\2993233576.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(r'../msedgedriver.exe', options=options) # ToDo better way of using driver files
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999

# %% [markdown]
# # Extract all column headers

# %%
import pandas as pd
import sys
from os.path import join
import os
import json
from glob import glob
from dotenv import load_dotenv
load_dotenv(override=True)


metadata = {}

tables = ["all_players", "all_stadiums", "all_teams", "playoff_player_goalie_stats", "playoff_player_stats",
          "playoff_standings", "season_player_goalie_stats", "season_player_stats", "season_standings", "all_nhl_teams", "nfl_WHA_and_Defunct_Franchise", "nhl_player_stats", "nhl_season_standings_Clarence_Campbell_Conference_&_Prince_of_Wales_Conference", "nhl_season_standings_League_Playoff_Series", "nhl_season_standings_League_Playoff_Series_final", "nhl_season_standings_League_Playoff_Series_semi_finals1", "nhl_season_standings_League_Playoff_Series_semi_finals2", "nhl_season_standings_League_Playoff_Series_quarter-finals1", "nhl_season_standings_League_Playoff_Series_quarter-finals2", "nhl_season_standings_League_Playoff_Series_quarter-finals3", "nhl_season_standings_League_Playoff_Series_quarter-finals4", "nhl_season_standings_League_Playoff_Series_conference_PreliminaryRound5", "nhl_season_standings_League_Playoff_Series_PreliminaryRound2", "nhl_league_playoff_series_conference_PreliminaryRound3", "nhl_league_playoff_series_conference_PreliminaryRound4", "nhl_league_playoff_series_conference_PreliminaryRound6", "nhl_league_playoff_series_conference_PreliminaryRound7", "nhl_league_playoff_series_conference_PreliminaryRound8", "nhl_teams_statics", "nhl_league_awards", "nhl_league_leaders_goals", "nhl_league_leaders_assists", "nhl_league_leaders_points", "nhl_league_leaders_goals_created", "nhl_league_leaders_plus_minus", "nfl_league_leaders_penalties_in_minutes", "nfl_Even_Strength_Goals", "nfl_league_power_play_goals", "nfl_league_shot_handed_goals", "nfl_league_leaders_game_winning_goals", "nfl_shots", "nfl_shooting_percentage", "nfl_league_leaders_hat_tricks","nfl_goals_per_game", "nfl_assists_per_game", "nfl_goals_created_per_game", "nfl_total_goals_on_ice_for","nfl_power_play_goals_on_ice_for", "nfl_total_goals_on_ice_against", "nfl_league_leaders_power_play_Goals_on_ice_Against", "nfl_games_played_goalie", "nfl_wins", "nfl_losses", "nfl_ties_plus_OTSO_losses", "nfl_goals_against", "nfl_shots_against", "nfl_saves", "save_percentage", "nfl_goals_against_average", "nfl_shutouts", "nfl_minutes", "nfl_goals_saved_above_average","nfl_goals_allowed_adjusted","nfl_offensive_point_shares","nfl_defensive_point_shares","goalie_point_shares", "nfl_point_shares", "nhl_player_goalie_stats", "nfl_league_playoff_series", "nfl_league_playoff_series_Conference_Finals", "nfl_league_playoff_series_Conference_Finals2", "nfl_league_playoff_series_division_finals", "nfl_league_playoff_series_division_finals2", "nfl_league_playoff_series_division_finals3", "nfl_league_playoff_series_division_finals4", "nfl_league_playoff_series_division_semi_finals1", "nfl_league_playoff_series_division_semi_finals2", "nfl_league_playoff_series_division_semi_finals3", "nfl_league_playoff_series_division_semi_finals4", "nfl_league_playoff_series_division_semi_finals5", "nfl_league_playoff_series_division_semi_finals6", "nfl_league_playoff_series_division_semi_finals7", "nfl_league_playoff_series_division_semi_finals8", "nfl_playoff_leaders_teams_statics", "nfl_playoff_leaders_overtime_goals", "nfl_playoff_leaders_goals", "nfl_playoff_leaders_goals_assists", "nfl_playoff_leaders_games_points", "nfl_playoff_leaders_goals_created", "nfl_playoff_leaders_plus-minus", " nfl_Even_Strength_Goals", "nfl_playoff_leaders_even_strength_for_goals", "nfl_playoff_leaders_saves_power_play_goals", "nfl_playoff_leaders_short_handed_goals", "nfl_playoff_leaders_game_winning_goals", "nfl_playoff_shots", "nfl_playoff_shooting_percentage", "nfl_playoff_leaders_hat_ticks", "nfl_playoff_leaders_goals_per_game", "nfl_playoff_leaders_assists_per_game", "nfl_playoff_leaders_points_per_game", "nfl_playoff_leaders_goals_created_per_game", "nfl_playoff_leaders_games_played_goalie", "nfl_playoff_leaders_wins", "nfl_playoff_leaders_losses", "nfl_playoff_leaders_goals_against", "nfl_playoff_leaders_shots_against", "nfl_playoff_leaders_saves", "nfl_playoff_leaders_save_percentage", "nfl_playoff_leaders_goals_against_average", "nfl_playoff_leaders_shutouts", "nfl_playoff_leaders_minutes", "nhl_playoff_player_stats", "nhl_playoff_player_goalies_stats", "nhl_hat_tricks", "nhl_penalty_shots", "nhl_debut", "nhl_finales", "nhl_births", "nhl_deaths" ]

for table in tables:
    column_names = []
    for found_table in glob(join(os.environ["SportsTables"], "hockey", f"*{table}*.csv")):
        column_names.extend(list(pd.read_csv(found_table).columns))

    column_names = list(set(column_names))
    metadata[table] = {}
    for column_name in column_names:
        metadata[table][column_name] = None

if os.path.isfile("metadata.json"):
    print("metadata.json exists already!!! ")
else:
    with open("metadata.json", "w") as f:
        json.dump(metadata, f)
