# %%
### extract all data for nfl
from dotenv import load_dotenv
load_dotenv(override=True)
import os
from os.path import join
import time
from selenium import webdriver

from web_scraping import web_table_to_dataframe, get_nhl_season_standings, get_all_nhl_teams, get_nhl_player_stats, get_nhl_player_goalie_stats, get_nhl_playoff_standings, get_nhl_playoff_player_stats, get_nhl_playoff_player_goalies_stats, get_nhl_season_standings_zusatz, get_nhl_hat_tricks, get_nhl_penalty_shots, get_nhl_debuts, get_nhl_final_season, get_nhl_births, get_nhl_deaths

options = webdriver.EdgeOptions()
options.add_argument('headless')
driver = webdriver.Edge(r'../msedgedriver.exe', options=options) # ToDo better way of using driver files


time.sleep(3)

df = get_all_nhl_teams(driver) # works
df[0].to_csv(join(os.environ["SportsTables"], "hockey", f"all_nhl_teams.csv"), index=False)
df[1].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_WHA_and_Defunct_Franchise_.csv"), index=False)

time.sleep(3)

for year in range(1980,2000):

    print(year)

'''
    df = get_nhl_player_stats(year, driver) # uses selenium
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_player_stats_{year}.csv"), index=False) #works

    time.sleep(3)


    df = get_nhl_season_standings(year,driver) # uses selenium
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_Clarence_Campbell_Conference_&_Prince_of_Wales_Conference_{year}.csv"), index=False)
    time.sleep(3)


    df = get_nhl_season_standings_zusatz(year, driver)

    df[0].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_{year}.csv"), index=False) #richtig
    df[1].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_final_{year}.csv"), index=False)#richtig
    df[2].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_semi_finals1_{year}.csv"), index=False)#richtig
    df[3].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_semi_finals2_{year}.csv"), index=False)#richtig
    df[4].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_quarter-finals1_{year}.csv"), index=False)#richtig
    df[5].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_quarter-finals2_{year}.csv"), index=False)

    df[6].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_quarter-finals3_{year}.csv"), index=False) #richtig
    df[7].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_quarter-finals4_{year}.csv"), index=False)
    df[8].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_conference_PreliminaryRound5_{year}.csv"), index=False)
    df[9].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_season_standings_League_Playoff_Series_PreliminaryRound2_{year}.csv"), index=False)
    df[10].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_playoff_series_conference_PreliminaryRound3_{year}.csv"), index=False)
    df[11].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_playoff_series_conference_PreliminaryRound4_{year}.csv"), index=False)
    df[12].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_playoff_series_conference_PreliminaryRound5_{year}.csv"), index=False)
    df[13].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_playoff_series_conference_PreliminaryRound6_{year}.csv"), index=False)
    df[14].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_playoff_series_conference_PreliminaryRound7_{year}.csv"), index=False)
    df[15].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_playoff_series_conference_PreliminaryRound8_{year}.csv"), index=False)
    df[16].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_teams_statics_{year}.csv"), index=False)
    df[17].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_awards_{year}.csv"), index=False)
    df[18].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_leaders_goals_{year}.csv"), index=False)
    df[19].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_leaders_assists_{year}.csv"), index=False)
    df[20].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_leaders_points_{year}.csv"), index=False)
    df[21].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_leaders_goals_created_{year}.csv"), index=False)
    df[22].to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_league_leaders_plus-minus_{year}.csv"), index=False)
    df[23].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_penalties_in_minutes_{year}.csv"), index=False)
    df[24].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_shots_{year}.csv"), index=False)
    df[25].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_power_play-goals_{year}.csv"), index=False)
    df[26].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_shot_handed_goals_{year}.csv"), index=False)
    df[27].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_game-winning_goals_{year}.csv"), index=False)
    df[28].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_shooting_percentage_{year}.csv"), index=False)
    df[29].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_hat_tricks_{year}.csv"), index=False)
    df[30].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_goals_per_game_{year}.csv"), index=False)
    df[31].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_points_per_game_{year}.csv"), index=False)
    df[32].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_total_total_goals_on_ice_for_{year}.csv"), index=False)
    df[33].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_total_play_goals_on_ice_against_{year}.csv"), index=False)
    df[34].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_power_play_goals_on_ice_against_{year}.csv"), index=False)
    df[35].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_Games_Played_(Goalie)_{year}.csv"), index=False)
    df[36].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_losses_{year}.csv"), index=False)
    df[37].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_Ties_plus_OT-SO_Losses_{year}.csv"), index=False)
    df[38].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_Goals_Against_{year}.csv"), index=False)
    df[39].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_saves_{year}.csv"), index=False)
    df[40].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_saved_percentage_{year}.csv"), index=False)
    df[41].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_Goals_Allowed_Adjusted_{year}.csv"), index=False)
    df[42].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_goals_against_average_{year}.csv"), index=False)
    df[43].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_shutouts_{year}.csv"), index=False)
    df[44].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_minutes_{year}.csv"), index=False)
    df[45].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_goals_saved_above_average_{year}.csv"), index=False)
    df[46].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_Offensive_Point_Shares_{year}.csv"), index=False)
    df[47].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_Defensive_Point_Shares_{year}.csv"), index=False)
    df[48].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_Goalie_Point_Shares_{year}.csv"), index=False)
    df[49].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_leaders_Point_Shares_{year}.csv"), index=False)


    time.sleep(3)


    df = get_nhl_player_goalie_stats(year, driver)
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_player_goalie_stats_{year}.csv"), index=False) #works

    time.sleep(3)


    df = get_nhl_playoff_standings(year, driver)
    df[0].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_{year}.csv"), index=False)
    df[2].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_Conference_Finals_{year}.csv"), index=False)
    df[3].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_Conference_Finals2_{year}.csv"), index=False)
    df[4].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_semi-finals_{year}.csv"), index=False)
    df[5].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_semi-finals2_{year}.csv"), index=False)
    df[6].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_semi_finals3_{year}.csv"), index=False)
    df[7].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_semi_finals4_{year}.csv"), index=False)
    df[8].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_conference_quarter-finals1_{year}.csv"), index=False)
    df[9].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_conference_quarter-finals2_{year}.csv"), index=False)
    df[10].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_conference_quarter-finals3_{year}.csv"), index=False)
    df[11].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_conference_quarter-finals4_{year}.csv"), index=False)
    df[12].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_conference_quarter-finals5_{year}.csv"), index=False)
    df[13].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_conference_quarter-finals6_{year}.csv"), index=False)
    df[14].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_conference_quarter-finals7_{year}.csv"), index=False)
    df[15].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_league_playoff_series_conference_quarter-finals8_{year}.csv"), index=False)
    df[16].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_teams_statics_{year}.csv"), index=False)
    df[17].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_overtime_goals_{year}.csv"), index=False)
    df[18].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_goals_{year}.csv"), index=False)
    df[19].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_goals_assists_{year}.csv"), index=False)
    df[20].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_games_points_{year}.csv"), index=False)
    df[21].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_goals_created_{year}.csv"), index=False)
    df[22].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_plus-minus_{year}.csv"), index=False)
    df[23].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_penalties_in_minutes__{year}.csv"), index=False)
    df[24].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_even_strength_for_goals_{year}.csv"), index=False)
    df[25].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_saves_power_play_goals{year}.csv"), index=False)
    df[26].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_short_handed_goals_{year}.csv"), index=False)
    df[27].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_game_winning_goals_{year}.csv"), index=False)
    df[28].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_shots_{year}.csv"), index=False)
    df[29].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_shooting_percentage_{year}.csv"), index=False)
    df[30].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_hat_ticks_{year}.csv"), index=False) #
    df[31].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_goals_per_game_{year}.csv"), index=False)
    df[32].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_assists_per_game_{year}.csv"), index=False)
    df[33].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_points_per_game_{year}.csv"), index=False)
    df[34].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_goals_created_per_game_{year}.csv"), index=False)
    df[35].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_games_played_goalie_{year}.csv"), index=False)
    df[36].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_wins_{year}.csv"), index=False)
    df[37].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_losses_{year}.csv"), index=False)
    df[38].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_goals_against_{year}.csv"), index=False)
    df[39].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_shots_against_{year}.csv"), index=False)
    df[40].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_saves_{year}.csv"), index=False)
    df[41].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_save_percentage_{year}.csv"), index=False)
    df[42].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_goals_against_average_{year}.csv"), index=False)
    df[43].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_shutouts_{year}.csv"), index=False)
    df[44].to_csv(join(os.environ["SportsTables"], "hockey", f"nfl_playoff_leaders_minutes_{year}.csv"), index=False)
    time.sleep(3)

    df = get_nhl_playoff_player_stats(year, driver) #works
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_playoff_player_stats_{year}.csv"), index=False)

    time.sleep(3)

    df = get_nhl_playoff_player_goalies_stats(year, driver)
    df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_playoff_player_goalies_stats_{year}.csv"), index=False) #works

    time.sleep(3)

'''
#FEHLENDE LINKS TABELLEN
df = get_nhl_hat_tricks(year, driver)
df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_hat_tricks_{year}.csv"), index=False) #works
time.sleep(3)


df = get_nhl_penalty_shots(year, driver)
df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_penalty_shots_{year}.csv"), index=False) #works
time.sleep(3)

df = get_nhl_debuts(year, driver)
df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_debut_{year}.csv"), index=False) #works
time.sleep(3)

df = get_nhl_final_season(year, driver)
df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_finales_{year}.csv"), index=False) #works
time.sleep(3)

df = get_nhl_births(year, driver)
df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_births_{year}.csv"), index=False) #works
time.sleep(3)

df = get_nhl_deaths(year, driver)
df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_deaths_{year}.csv"), index=False) #works
time.sleep(3)

driver.quit()
# Out:
# C:\Users\krist\AppData\Local\Temp\ipykernel_19400\115821802.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(r'../msedgedriver.exe', options=options) # ToDo better way of using driver files
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# Cell In[1], line 165
#      28 '''
#      29     df = get_nhl_player_stats(year, driver) # uses selenium
#      30     df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_player_stats_{year}.csv"), index=False) #works
#    (...)
#     160
#     161 '''
#     162 #FEHLENDE LINKS TABELLEN
# --> 165 df = get_nhl_penalty_shots(year, driver)
#     166 df.to_csv(join(os.environ["SportsTables"], "hockey", f"nhl_penalty_shots_{year}.csv"), index=False) #works
#     167 time.sleep(3)
#
# File ~\Integrationsseminar\hockey\web_scraping.py:114, in get_nhl_penalty_shots(year, driver)
#     107 ''' response = requests.get(f"https://www.hockey-reference.com/leagues/NHL_{year}_skaters.html")
#     108   soup = BeautifulSoup(response.content, "html.parser")
#     109   df = web_table_to_dataframe(soup("table")[0])
#     110   return df
#     111 '''
#     113 result = None
# --> 114 driver.get(f"www.hockey-reference.com/leagues/NHL_{year}_penalty-shots.html")
#     117 try:
#     118     tables = driver.find_elements(By.TAG_NAME, "table")
#
# File ~\anaconda3\envs\Integrationsseminar\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.get(self, url)
#     436 def get(self, url: str) -> None:
#     437     """
#     438     Loads a web page in the current browser session.
#     439     """
# --> 440     self.execute(Command.GET, {'url': url})
#
# File ~\anaconda3\envs\Integrationsseminar\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File ~\anaconda3\envs\Integrationsseminar\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# InvalidArgumentException: Message: invalid argument
#   (Session info: headless MicrosoftEdge=113.0.1774.50)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF6D2C93472+67490]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6D2C29402+786594]
# 	(No symbol) [0x00007FF6D29CC4E7]
# 	(No symbol) [0x00007FF6D29B8CCD]
# 	(No symbol) [0x00007FF6D29B6EA2]
# 	(No symbol) [0x00007FF6D29B7376]
# 	(No symbol) [0x00007FF6D29CE5C6]
# 	(No symbol) [0x00007FF6D2A47771]
# 	(No symbol) [0x00007FF6D2A2DF4A]
# 	(No symbol) [0x00007FF6D2A03751]
# 	(No symbol) [0x00007FF6D2A46BC5]
# 	(No symbol) [0x00007FF6D2A2DD23]
# 	(No symbol) [0x00007FF6D2A02794]
# 	(No symbol) [0x00007FF6D2A019B0]
# 	(No symbol) [0x00007FF6D2A02F04]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x00007FF6D2E5EC83+1309699]
# 	(No symbol) [0x00007FF6D2A822C8]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6D2B71821+33985]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6D2B69C55+2293]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x00007FF6D2E5D9D3+1304915]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6D2C30749+816105]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6D2C2D0C4+802148]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6D2C2D1BC+802396]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6D2C23271+761617]
# 	BaseThreadInitThunk [0x00007FFB9CF226AD+29]
# 	RtlUserThreadStart [0x00007FFB9E4CA9F8+40]
